# %%
#se debe instalar ipyleaflet, mpu, openpyxl y requests

import requests
from pandas import json_normalize
import ipyleaflet
import mpu
import pandas as pd
import numpy as np
from ipyleaflet import Map, basemaps, Marker, AwesomeIcon, Icon

# %% [markdown]
# ## Íconos y mapas a usar luego

# %%
basic_map = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=(-34.60823238941058, -58.398160858739075), zoom=14)

icono_subte = Icon(icon_url='icono_subte.png', icon_size=[28, 28])

icon0 = AwesomeIcon(
    name='home',
    marker_color='green',
    icon_color='black',
    spin=False
)

icon1 = AwesomeIcon(
    name='home',
    marker_color='beige',
    icon_color='black',
    spin=False
)

icon2 = AwesomeIcon(
    name='home',
    marker_color='orange',
    icon_color='black',
    spin=False
)

icon3 = AwesomeIcon(
    name='home',
    marker_color='red',
    icon_color='black',
    spin=False
)

# %% [markdown]
# ## Estaciones a usar luego

# %%
# direccion web para acceder a los datos del gobierno de la ciudad
url = 'https://cdn.buenosaires.gob.ar/datosabiertos/datasets/subte-estaciones/subte_estaciones.geojson'
response = requests.get(url)
dictr = response.json()
# referencio a las estaciones dentro del conjunto de datos
estaciones = dictr['features']
df = json_normalize(estaciones)
# creo la columna Latitud
df['Latitud'] = df['geometry.coordinates'].apply(lambda x:x[0])
# creo la columna Longitud
df['Longitud'] = df['geometry.coordinates'].apply(lambda x:x[1])
# creo la máscara para filtrar los de Linea A
mascara_linea_a = df['properties.LINEA'] == 'A'
linea_a = df.loc[mascara_linea_a, :]
linea_a_limpio = linea_a.drop(['type', 'properties.ID', 'properties.LINEA', 'geometry.type', 'geometry.coordinates'], axis = 1)
linea_a_limpio
# Out:
#                       properties.ESTACION    Latitud   Longitud
# 30                                   PERU -58.374268 -34.608559
# 31                                PIEDRAS -58.379085 -34.608882
# 32                                   LIMA -58.382232 -34.609100
# 33                             SAENZ PEÑA -58.386777 -34.609413
# 34  CONGRESO - PDTE. DR. RAÚL R. ALFONSÍN -58.392669 -34.609226
# 35                                  PASCO -58.398427 -34.609646
# 36                                ALBERTI -58.401208 -34.609834
# 37                      PLAZA DE MISERERE -58.406707 -34.609817
# 38                                  LORIA -58.415186 -34.610782
# 39                          CASTRO BARROS -58.421816 -34.611770
# 40                         RIO DE JANEIRO -58.429500 -34.615206
# 41                                 ACOYTE -58.436429 -34.618280
# 42                          PRIMERA JUNTA -58.441178 -34.620405
# 69                          PLAZA DE MAYO -58.370968 -34.608810
# 74                               CARABOBO -58.456710 -34.626667
# 75                                   PUAN -58.448648 -34.623529
# 81                            SAN PEDRITO -58.469640 -34.630707
# 82                     SAN JOSÉ DE FLORES -58.463541 -34.629087

# %% [markdown]
# ## Funciones

# %%
def distancia(lat, long):
    aux = []
    for index, row in linea_a_limpio.iterrows():
        aux.append(
            mpu.haversine_distance(
                (row['Latitud'], row['Longitud']), 
                (lat, long)
            )
        )
    return min(aux)

def marca_propiedad(lat, long, quantile):
    if quantile == 0:
        icono_prop = icon0
    elif quantile == 1:
        icono_prop = icon1
    elif quantile == 2:
        icono_prop = icon2  
    else: 
        icono_prop = icon3
    marker = Marker(location=(lat,long), draggable=False, icon=icono_prop)
    basic_map.add_layer(marker)
    
def limpieza_superficie(sup_total, sup_cubierta):
    if sup_total is not None and sup_cubierta is not None:
            if sup_total >= sup_cubierta:
                superficie = sup_total
            else: 
                superficie = 0
    elif sup_total is not None:
            superficie = sup_total
    elif sup_cubierta is not None:
            superficie = sup_cubierta
    else: superficie = 0        
                    
    return superficie

# %% [markdown]
# ## Lectura del dataset Original de Properati

# %%
df_properati = pd.read_csv('properati.csv')

# %% [markdown]
# ## Genera df solo para Capital

# %%
df_capital = df_properati[df_properati["state_name"] == "Capital Federal"]
df_capital.shape
# Out:
# (32316, 26)

# %%
Barrios = df_capital["place_name"].value_counts()

# %% [markdown]
# ## Corrige ortografia de Barrios y mapea Barrios Inexistentes

# %%
# %%capture output
df_capital["place_name"].replace(['San Cristobal','Barrio Norte', 'Centro / Microcentro'], ['San Cristóbal','Recoleta', 'Monserrat'], inplace=True)

# %%
barrios_conv = df_capital["place_name"].value_counts()

# %% [markdown]
# ## Lee el archivo de Mapping de Barrios por Comuna

# %%
df_barrios_comuna = pd.read_csv("Barrios_x_Comuna_vsc_utf8.csv")

# %% [markdown]
# ## Merge de df de Barrios de Capital con Comunas

# %%
df_capital_comuna = pd.merge(df_capital, df_barrios_comuna, how='left', left_on='place_name', right_on='Barrio')
del df_capital_comuna["description"]
del df_capital_comuna["title"]
del df_capital_comuna["properati_url"]
del df_capital_comuna["image_thumbnail"]

# %%
df_capital_comuna["Comuna"].isna().sum()
# Out:
# 3612

# %% [markdown]
# ## Enumera los Barrrios por los que atraviesa la Linea A

# %%
barrios_linea_a = pd.Series(['Monserrat', 'Balvanera', 'Almagro', 'Caballito'])
barrios_linea_a
# Out:
# 0    Monserrat
# 1    Balvanera
# 2      Almagro
# 3    Caballito
# dtype: object

# %% [markdown]
# ## Filtra el df de Capital por los Barrios definidos

# %%
df_capital_barrios_subte = df_capital_comuna[df_capital_comuna['Barrio'].isin(barrios_linea_a)]
df_capital_barrios_subte.shape
# Out:
# (4866, 24)

# %% [markdown]
# ## Elimina los Registros sin lat-long

# %%
df_latlon_notna = df_capital_barrios_subte[df_capital_barrios_subte['lat-lon'].notna()]

# %%
df_latlon_notna.shape
# Out:
# (4031, 24)

# %% [markdown]
# ## Calcula las distancias de cada Propiedad hasta las 17 estaciones

# %%
# %%capture output
df_latlon_notna['distancia'] = df_latlon_notna.apply(lambda x: distancia(x['lat'], x['lon']), axis=1)
df_latlon_notna

# %%
# %%capture output
df_latlon_notna.loc["superficie"] = df_latlon_notna[['surface_total_in_m2','surface_covered_in_m2']].apply(lambda df_latlon_notna: limpieza_superficie(df_latlon_notna['surface_total_in_m2'],df_latlon_notna['surface_covered_in_m2']),axis=1)
df_latlon_notna.head(4)

# %% [markdown]
# ## Exportamos a CSV

# %%
df_latlon_notna.to_csv("CSV_notna.csv", index=False)

# %% [markdown]
# ## Seguimos eliminando NA

# %%
df_price_notna = df_latlon_notna[df_latlon_notna['price_usd_per_m2'].notna()]
df_price_notna
# Out:
#        Unnamed: 0 operation property_type place_name  \
# 14           48.0      sell     apartment  Balvanera
# 16           52.0      sell     apartment  Caballito
# 17           53.0      sell     apartment  Caballito
# 18           54.0      sell     apartment  Caballito
# 19           55.0      sell     apartment  Caballito
# ...           ...       ...           ...        ...
# 31793    119970.0      sell     apartment  Balvanera
# 31817    120075.0      sell     apartment  Caballito
# 32198    120984.0      sell     apartment  Caballito
# 32267    121059.0      sell     apartment  Monserrat
# 32273    121075.0      sell     apartment  Caballito
#
#                      place_with_parent_names country_name       state_name  \
# 14     |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
# 16     |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 17     |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 18     |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 19     |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# ...                                      ...          ...              ...
# 31793  |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
# 31817  |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 32198  |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 32267  |Argentina|Capital Federal|Monserrat|    Argentina  Capital Federal
# 32273  |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
#
#        geonames_id                        lat-lon        lat  ...  \
# 14       6693228.0        -34.6096748,-58.3986588 -34.609675  ...
# 16       3435874.0        -34.6222111,-58.4391283 -34.622211  ...
# 17       3435874.0  -34.6238943143,-58.4468606529 -34.623894  ...
# 18       3435874.0        -34.6209278,-58.4458736 -34.620928  ...
# 19       3435874.0        -34.6209278,-58.4458736 -34.620928  ...
# ...            ...                            ...        ...  ...
# 31793    6693228.0        -34.6096441,-58.3964932 -34.609644  ...
# 31817    3435874.0  -34.6221978289,-58.4291563359 -34.622198  ...
# 32198    3435874.0  -34.6204033093,-58.4410224908 -34.620403  ...
# 32267    3430570.0   -34.613408336,-58.3845426597 -34.613408  ...
# 32273    3435874.0   -34.627466548,-58.4386614795 -34.627467  ...
#
#        surface_total_in_m2  surface_covered_in_m2 price_usd_per_m2  \
# 14                   141.0                  124.0      1702.127660
# 16                    50.0                   50.0      2200.000000
# 17                   100.0                   46.0      1705.000000
# 18                    81.0                   75.0      2721.111111
# 19                    81.0                   75.0      2750.370370
# ...                    ...                    ...              ...
# 31793                 45.0                   38.0      2631.111111
# 31817                 78.0                   70.0      2051.282051
# 32198                 77.0                   77.0      1909.090909
# 32267                 37.0                   34.0      2310.810811
# 32273                 91.0                   83.0      3461.538462
#
#        price_per_m2  floor  rooms  expenses     Barrio    Comuna    distancia
# 14      1935.483871    NaN    5.0       NaN  Balvanera  Comuna-3  3172.512042
# 16      2200.000000    NaN    3.0       NaN  Caballito  Comuna-6  3172.903899
# 17      3706.521739    NaN    2.0       NaN  Caballito  Comuna-6  3173.050028
# 18      2938.800000    NaN    3.0       NaN  Caballito  Comuna-6  3173.305581
# 19      2970.400000    NaN    3.0       NaN  Caballito  Comuna-6  3173.305581
# ...             ...    ...    ...       ...        ...       ...          ...
# 31793   3115.789474    NaN    1.0       NaN  Balvanera  Comuna-3  3172.427328
# 31817   2285.714286    NaN    NaN    2300.0  Caballito  Comuna-6  3172.500548
# 32198   1909.090909    NaN    NaN    3800.0  Caballito  Comuna-6  3173.160941
# 32267   2514.705882    NaN    NaN    1200.0  Monserrat  Comuna-1  3171.567746
# 32273   3795.180723    NaN    NaN    3000.0  Caballito  Comuna-6  3172.361211
#
# [3024 rows x 25 columns]

# %%
df_randomizado = df_price_notna.sample(n=10, random_state = 100)
df_randomizado.head(10)
# Out:
#        Unnamed: 0 operation property_type place_name  \
# 9331      36566.0      sell     apartment  Balvanera
# 28856    110461.0      sell     apartment    Almagro
# 29180    111497.0      sell     apartment    Almagro
# 5851      24942.0      sell     apartment  Caballito
# 14770     56081.0      sell     apartment  Balvanera
# 13120     49742.0      sell     apartment  Balvanera
# 18778     71765.0      sell     apartment  Caballito
# 4524      19659.0      sell     apartment    Almagro
# 2722      12321.0      sell     apartment    Almagro
# 5269      22759.0      sell     apartment  Balvanera
#
#                      place_with_parent_names country_name       state_name  \
# 9331   |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
# 28856    |Argentina|Capital Federal|Almagro|    Argentina  Capital Federal
# 29180    |Argentina|Capital Federal|Almagro|    Argentina  Capital Federal
# 5851   |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 14770  |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
# 13120  |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
# 18778  |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 4524     |Argentina|Capital Federal|Almagro|    Argentina  Capital Federal
# 2722     |Argentina|Capital Federal|Almagro|    Argentina  Capital Federal
# 5269   |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
#
#        geonames_id                        lat-lon        lat  ...  \
# 9331     6693228.0        -34.6051224,-58.4046096 -34.605122  ...
# 28856    3436397.0        -34.6110583,-58.4201892 -34.611058  ...
# 29180    3436397.0         -34.6110268,-58.424513 -34.611027  ...
# 5851     3435874.0        -34.6113092,-58.4381058 -34.611309  ...
# 14770    6693228.0          -34.609032,-58.403378 -34.609032  ...
# 13120    6693228.0  -34.6133124313,-58.4052081146 -34.613312  ...
# 18778    3435874.0   -34.6060340291,-58.452885322 -34.606034  ...
# 4524     3436397.0        -34.6032835,-58.4328461 -34.603284  ...
# 2722     3436397.0        -34.6051042,-58.4129088 -34.605104  ...
# 5269     6693228.0         -34.602203,-58.3985049 -34.602203  ...
#
#        surface_total_in_m2  surface_covered_in_m2 price_usd_per_m2  \
# 9331                  45.0                   45.0      1988.888889
# 28856                 90.0                   77.0      2111.111111
# 29180                 60.0                   45.0      1566.666667
# 5851                 190.0                  170.0      1684.210526
# 14770                 70.0                   70.0      1714.285714
# 13120                 46.0                   42.0      2304.347826
# 18778                 47.0                   40.0      2836.170213
# 4524                  93.0                   85.0      2741.935484
# 2722                  77.0                   72.0      1753.246753
# 5269                  74.0                   68.0      1594.594595
#
#        price_per_m2  floor  rooms  expenses     Barrio    Comuna    distancia
# 9331    1988.888889    NaN    2.0       NaN  Balvanera  Comuna-3  3173.207101
# 28856   2467.532468    NaN    4.0       NaN    Almagro  Comuna-5  3173.247080
# 29180   2088.888889    NaN    3.0       NaN    Almagro  Comuna-5  3173.425595
# 5851    1882.352941    NaN    5.0       NaN  Caballito  Comuna-6  3173.948914
# 14770   1714.285714    4.0    3.0    2000.0  Balvanera  Comuna-3  3172.767417
# 13120   2523.809524    5.0    2.0    1700.0  Balvanera  Comuna-3  3172.414895
# 18778   3332.500000    NaN    NaN       NaN  Caballito  Comuna-6  3175.074480
# 4524    3000.000000    NaN    4.0    3100.0    Almagro  Comuna-5  3174.535446
# 2722    1875.000000    NaN    3.0    2300.0    Almagro  Comuna-5  3173.545373
# 5269    1735.294118    NaN    3.0       NaN  Balvanera  Comuna-3  3173.250722
#
# [10 rows x 25 columns]

# %%
df_randomizado['quantile'] = pd.qcut(df_randomizado['price_usd_per_m2'], 4, labels=False)
df_randomizado
# Out:
#        Unnamed: 0 operation property_type place_name  \
# 9331      36566.0      sell     apartment  Balvanera
# 28856    110461.0      sell     apartment    Almagro
# 29180    111497.0      sell     apartment    Almagro
# 5851      24942.0      sell     apartment  Caballito
# 14770     56081.0      sell     apartment  Balvanera
# 13120     49742.0      sell     apartment  Balvanera
# 18778     71765.0      sell     apartment  Caballito
# 4524      19659.0      sell     apartment    Almagro
# 2722      12321.0      sell     apartment    Almagro
# 5269      22759.0      sell     apartment  Balvanera
#
#                      place_with_parent_names country_name       state_name  \
# 9331   |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
# 28856    |Argentina|Capital Federal|Almagro|    Argentina  Capital Federal
# 29180    |Argentina|Capital Federal|Almagro|    Argentina  Capital Federal
# 5851   |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 14770  |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
# 13120  |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
# 18778  |Argentina|Capital Federal|Caballito|    Argentina  Capital Federal
# 4524     |Argentina|Capital Federal|Almagro|    Argentina  Capital Federal
# 2722     |Argentina|Capital Federal|Almagro|    Argentina  Capital Federal
# 5269   |Argentina|Capital Federal|Balvanera|    Argentina  Capital Federal
#
#        geonames_id                        lat-lon        lat  ...  \
# 9331     6693228.0        -34.6051224,-58.4046096 -34.605122  ...
# 28856    3436397.0        -34.6110583,-58.4201892 -34.611058  ...
# 29180    3436397.0         -34.6110268,-58.424513 -34.611027  ...
# 5851     3435874.0        -34.6113092,-58.4381058 -34.611309  ...
# 14770    6693228.0          -34.609032,-58.403378 -34.609032  ...
# 13120    6693228.0  -34.6133124313,-58.4052081146 -34.613312  ...
# 18778    3435874.0   -34.6060340291,-58.452885322 -34.606034  ...
# 4524     3436397.0        -34.6032835,-58.4328461 -34.603284  ...
# 2722     3436397.0        -34.6051042,-58.4129088 -34.605104  ...
# 5269     6693228.0         -34.602203,-58.3985049 -34.602203  ...
#
#        surface_covered_in_m2  price_usd_per_m2 price_per_m2  floor  rooms  \
# 9331                    45.0       1988.888889  1988.888889    NaN    2.0
# 28856                   77.0       2111.111111  2467.532468    NaN    4.0
# 29180                   45.0       1566.666667  2088.888889    NaN    3.0
# 5851                   170.0       1684.210526  1882.352941    NaN    5.0
# 14770                   70.0       1714.285714  1714.285714    4.0    3.0
# 13120                   42.0       2304.347826  2523.809524    5.0    2.0
# 18778                   40.0       2836.170213  3332.500000    NaN    NaN
# 4524                    85.0       2741.935484  3000.000000    NaN    4.0
# 2722                    72.0       1753.246753  1875.000000    NaN    3.0
# 5269                    68.0       1594.594595  1735.294118    NaN    3.0
#
#        expenses     Barrio    Comuna    distancia  quantile
# 9331        NaN  Balvanera  Comuna-3  3173.207101         2
# 28856       NaN    Almagro  Comuna-5  3173.247080         2
# 29180       NaN    Almagro  Comuna-5  3173.425595         0
# 5851        NaN  Caballito  Comuna-6  3173.948914         0
# 14770    2000.0  Balvanera  Comuna-3  3172.767417         1
# 13120    1700.0  Balvanera  Comuna-3  3172.414895         3
# 18778       NaN  Caballito  Comuna-6  3175.074480         3
# 4524     3100.0    Almagro  Comuna-5  3174.535446         3
# 2722     2300.0    Almagro  Comuna-5  3173.545373         1
# 5269        NaN  Balvanera  Comuna-3  3173.250722         0
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Basic Map

# %%
## basic_map = Map(basemap=basemaps.Esri.DeLorme, center=(4.6097, -74.08), zoom=6)

for index, row in linea_a_limpio.iterrows():
    marker = Marker(location=(row['Latitud'],row['Longitud']), draggable=False, icon=icono_subte)
    basic_map.add_layer(marker);

display(basic_map)
# Out:
# Map(center=[-34.60823238941058, -58.398160858739075], controls=(ZoomControl(options=['position', 'zoom_in_text…

# %% [markdown]
# ## Exportamos un .CSV

# %%
df_randomizado.to_csv("df_randomizado.csv", index=False)
